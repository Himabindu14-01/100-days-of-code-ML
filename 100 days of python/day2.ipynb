# %%
#datatypes
x="string"
y=20
z=["apple","banana","guava"]
a=20.3
b=0+2j
c=("apple","banana","guava")
d={'name':'bindu','age':19}
e=True
f=bool(5)
g=bytes(5)
h=bytearray(5)
print(a,b,c,d,e,f,g,h)
print(type(a))
print(type(c))
print(type(d))
print(type(e))
print(type(f))
print(type(g))
print(type(h))
# Out:
# 20.3 2j ('apple', 'banana', 'guava') {'name': 'bindu', 'age': 19} True True b'\x00\x00\x00\x00\x00' bytearray(b'\x00\x00\x00\x00\x00')
# <class 'float'>
# <class 'tuple'>
# <class 'dict'>
# <class 'bool'>
# <class 'bool'>
# <class 'bytes'>
# <class 'bytearray'>

# %%
#type conversion
x=20
y=float(x)
print(x,y)
# Out:
# 20 20.0

# %%
#random number to print this we use random buidin module to make random numbers
import random
print(random.randrange(20,50))
# Out:
# 23

# %%
#type casting
x = float(1)     # x will be 1.0
y = float(2.8)   # y will be 2.8
z = float("3")   # z will be 3.0
w = float("4.2") # w will be 4.2
print(x)
print(y)
print(z)
print(w)
# Out:
# 1.0
# 2.8
# 3.0
# 4.2

# %%
#strings
a="bindu"
print(a)
#single quote
a='hima'
print(a)
# Out:
# bindu
# hima

# %%
#multiline string
a = """Lorem ipsum dolor sit amet,
consectetur adipiscing elit,
sed do eiusmod tempor incididunt
ut labore et dolore magna aliqua."""
print(a)
# Out:
# Lorem ipsum dolor sit amet,
# consectetur adipiscing elit,
# sed do eiusmod tempor incididunt
# ut labore et dolore magna aliqua.

# %%
#strings are arrays
a="bindu"
print(a[1])
# Out:
# i

# %%
#looping the string
for i in "hima":
 print(i)
# Out:
# h
# i
# m
# a

# %%
#string len
a="bindu"
print(len(a))
# Out:
# 5

# %%
#checkstring
a="bindu"
print("n"in a)
# Out:
# True

# %%
a="bindu"
print("d" not in a)
# Out:
# False

# %%
#slicing
a="bindu"
print(a[2:4])
# Out:
# nd

# %%
#slice from the end of the string:
a="bindu"
print(a[-1:-3])
