# %%
#day5 of python life
#stats function
num=[3,5,2,7,8]
def stat():
    max=num[0]
    min=num[0]
    total=0
    for n in num:
        if n<min:
            min=n
            if n>max:
                max=n
                totat+=n
                return min,max,total

# %%
print('hello')
# Out:
# hello

# %%
#functions
def greet():
    print('hello')
